# %% [markdown]
# # Notebook Fixture
#
# Rendered by **anyview**.
#
# - one
# - two

# %%
import numpy as np
print("sum =", sum(range(5)))
# Out:
# sum = 10
# array([0, 1, 2, 3, 4])

# %%
raise ValueError("boom")
# Out:
# ValueError: boom
